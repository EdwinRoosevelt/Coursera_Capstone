# %% [markdown]
# # **CAPSTONE PROJECT | FINDING BEST NEIGHBORHOODS IN CHENNAI**

# %% [markdown]
# #### INTRODUCTION/BUSINESS PROBLEM
#
# <p>The aim of the Project is to help people with finding their right Neighbourhood. It will help people make smart and efficient decision on selecting great neighborhood.</p>
#
# <p> Chennai is the capital of the Indian state of Tamil Nadu. It is one of the largest cultural, economic and educational centres of south India. It is among the most-visited Indian cities by foreign tourists. The availablity of jobs here attracts a lot of migrating people. With such a vast area and plethora of neighbour, finding the perfect place to live can become a tedious job.</p>
#
# <p> This project aims to find best neighborhoods in Chennai and make the job easy for those who are new in town.It will help people make smart and efficient decision on selecting their prefect neighborhood. For ease of accessing to Cafe, School, Hospital, medical shops, grocery shops, mall, theatre, etc.</p>

# %% [markdown]
# #### DATA
#
# List of Neighborhoods in chenani is obtained from *wikipedia*.
# https://en.wikipedia.org/wiki/List_of_neighbourhoods_of_Chennai
#
#
# Coordinates data is obtained using *geoPy api*.
#
# Each neighbourhood is explored using *Foursquare api*.
